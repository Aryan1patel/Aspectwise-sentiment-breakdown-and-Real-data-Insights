# %%
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize

nltk.download("punkt")
nltk.download("punkt_tab")


DATA_PATH = "../data/processed/mobile_reviews_absa.csv"
df = pd.read_csv(DATA_PATH)

df.shape
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/aryanpatel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/aryanpatel/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# (174249, 7)

# %%
ASPECTS = {
    "battery": ["battery", "charge", "charging", "power"],
    "camera": ["camera", "photo", "picture", "video"],
    "display": ["screen", "display", "resolution"],
    "performance": ["performance", "speed", "lag", "slow", "fast"],
    "build_quality": ["build", "quality", "durable", "sturdy"],
    "price": ["price", "cost", "value", "worth"],
    "software": ["software", "ui", "interface", "os", "update"]
}

# %%
def split_into_sentences(text):
    if not text or not isinstance(text, str):
        return []
    return sent_tokenize(text)

# %%
df["sentences"] = df["clean_review"].apply(split_into_sentences)
df[["clean_review", "sentences"]].head(10)
# Out:
#                                         clean_review  \
# 0  it works good but it goes slow sometimes but i...
# 1  i already had a phone with problems... i know ...
# 2  the charging port was loose. i got that solder...
# 3  phone looks good but wouldn't stay charged, ha...
# 4  i originally was using the samsung s2 galaxy f...
# 5  it's battery life is great. it's very responsi...
# 6  i was able to get the phone i previously owned...
# 7  i love the phone. it does everything i need an...
# 8  the battery was old & had been over used becau...
# 9  pros-beautiful screen,capable of running chrom...
#
#                                            sentences
# 0  [it works good but it goes slow sometimes but ...
# 1  [i already had a phone with problems... i know...
# 2  [the charging port was loose., i got that sold...
# 3  [phone looks good but wouldn't stay charged, h...
# 4  [i originally was using the samsung s2 galaxy ...
# 5  [it's battery life is great., it's very respon...
# 6  [i was able to get the phone i previously owne...
# 7  [i love the phone., it does everything i need ...
# 8  [the battery was old & had been over used beca...
# 9  [pros-beautiful screen,capable of running chro...

# %%
sentence_df = df.explode("sentences").reset_index(drop=True)
sentence_df = sentence_df[sentence_df["sentences"].str.len() > 0]

# %%
sentence_df = sentence_df.rename(columns={"sentences": "sentence"})

# %%
ASPECT_DICT = {
    "battery": ["battery", "battery life", "charge", "charging"],
    "camera": ["camera", "photo", "picture", "video"],
    "display": ["screen", "display", "resolution"],
    "performance": ["performance", "speed", "lag", "slow", "fast"],
    "build": ["build", "quality", "design"],
    "price": ["price", "cost", "value", "worth"]
}

# %%
def extract_sentence_aspects(sentence):
    sentence = sentence.lower()
    aspects = []
    for aspect, keywords in ASPECT_DICT.items():
        if any(k in sentence for k in keywords):
            aspects.append(aspect)
    return aspects

# %%
sentence_df["sentence_aspects"] = sentence_df["sentence"].apply(extract_sentence_aspects)

# %%
sentence_df = sentence_df[sentence_df["sentence_aspects"].str.len() > 0]

# %%
sentence_df = sentence_df.explode("sentence_aspects")
sentence_df = sentence_df.rename(columns={"sentence_aspects": "aspect"})

# %%
sentence_df[[
    "Product Name",
    "Brand Name",
    "Rating",
    "sentence",
    "aspect"
]].head()
# Out:
#                                         Product Name Brand Name  Rating  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung       4
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung       1
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung       1
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung       2
# 5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung       2
#
#                                             sentence       aspect
# 0  it works good but it goes slow sometimes but i...  performance
# 1  i already had a phone with problems... i know ...      battery
# 2  i wish i would have read these comments then i...      battery
# 3                       the charging port was loose.      battery
# 5                 then needed a new battery as well.      battery

# %% [markdown]
# cos diffrent sentence have diffrent sentiment

# %%
import joblib
import re

# load trained pipeline
sentiment_model = joblib.load("../data/sentiment_model.joblib")




# reuse SAME cleaning function
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

sentence_df["sentiment"] = sentiment_model.predict(
    sentence_df["sentence"].apply(clean_text)
)

sentence_df.head()
# Out:
# /Users/aryanpatel/Desktop/absa-project/venv/lib/python3.13/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/aryanpatel/Desktop/absa-project/venv/lib/python3.13/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/aryanpatel/Desktop/absa-project/venv/lib/python3.13/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/aryanpatel/Desktop/absa-project/venv/lib/python3.13/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                       clean_review  \
# 0       4  it works good but it goes slow sometimes but i...
# 1       1  i already had a phone with problems... i know ...
# 2       1  i already had a phone with problems... i know ...
# 3       2  the charging port was loose. i got that solder...
# 5       2  the charging port was loose. i got that solder...
#
#                 aspects  aspect_count  \
# 0       ['performance']             1
# 1           ['battery']             1
# 2           ['battery']             1
# 3  ['battery', 'price']             2
# 5  ['battery', 'price']             2
#
#                                             sentence       aspect sentiment
# 0  it works good but it goes slow sometimes but i...  performance   neutral
# 1  i already had a phone with problems... i know ...      battery  negative
# 2  i wish i would have read these comments then i...      battery  negative
# 3                       the charging port was loose.      battery  negative
# 5                 then needed a new battery as well.      battery  positive

# %%
aspect_summary = (
    sentence_df
    .groupby("aspect")["sentiment"]
    .value_counts()
    .unstack()
    .fillna(0)
)

aspect_summary
# Out:
# sentiment    negative  neutral  positive
# aspect
# battery         29353    22627     31458
# build            5945     7721     17602
# camera          12645    17250     28562
# display         21037    18470     25702
# performance      8642    11349     33513
# price            7487    12514     34751

# %%
sentence_df.to_csv("../data/processed/final_absa_results.csv", index=False)

# %%
probs = sentiment_model.predict_proba(
    sentence_df["sentence"].apply(clean_text)
)

# %%
preds = sentiment_model.predict(
    sentence_df["sentence"].apply(clean_text)
)

sentence_df["sentiment"] = preds
sentence_df["confidence"] = probs.max(axis=1)

# %%
final_output = (
    sentence_df[["sentence", "aspect", "sentiment", "confidence"]]
    .to_dict(orient="records")
)

final_output[:2]
# Out:
# [{'sentence': 'it works good but it goes slow sometimes but its a very good phone i love it',
#   'aspect': 'performance',
#   'sentiment': 'neutral',
#   'confidence': 0.623313972280907},
#  {'sentence': 'i already had a phone with problems... i know it stated it was used, but dang, it did not state that it did not charge.',
#   'aspect': 'battery',
#   'sentiment': 'negative',
#   'confidence': 0.5267655634257146}]
